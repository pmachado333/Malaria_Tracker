# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.12 torch-2.0.1+cu117 CUDA:0 (Quadro RTX 4000, 8192MiB)
# Setup complete ✅ (12 CPUs, 31.3 GB RAM, 56.9/250.9 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.12 torch-2.0.1+cu117 CUDA:0 (Quadro RTX 4000, 8192MiB)
# Setup complete ✅ (12 CPUs, 31.3 GB RAM, 65.8/250.9 GB disk)

# %%
# !pwd
# Out:
# /home/pmachado3/code/DDS_bootcamp_project/Malaria_Tracker/jupyter_notebook

# %%
# %cd ../raw_data/task_2/parasite/YOLO_FORMAT_4
# Out:
# /home/pmachado3/code/DDS_bootcamp_project/Malaria_Tracker/raw_data/task_2/parasite/YOLO_FORMAT_4

# %% [markdown]
# ### Run the training model

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="data.yaml" project = '../runs_draft/'\
epochs=5000 patience=20 imgsz=600 batch=8
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.12 torch-2.0.1+cu117 CUDA:0 (Quadro RTX 4000, 8192MiB)
# ...

# %%
# !pwd
# Out:
# /home/pmachado3/code/DDS_bootcamp_project/Malaria_Tracker/raw_data/task_2/parasite/YOLO_FORMAT_4

# %% [markdown]
# ### Evaluate the best model -- You need to change the train folder inside run_draft for the current run

# %%
# !yolo val model='/home/pmachado3/code/DDS_bootcamp_project/Malaria_Tracker/models/best_multiclass.pt'  \
data="data.yaml" \
project = '../runs_draft/'
# Out:
# 2023-05-25 13:40:42.294286: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.12 torch-2.0.1+cu117 CUDA:0 (Quadro RTX 4000, 8192MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /home/pmachado3/code/DDS_bootcamp_project/Malaria_Tracker/raw_data
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        298      0.868      0.868      0.938      0.664
#          0- falciparum         38        276        0.9      0.855      0.906      0.519
#            1- malariae         38          5      0.783          1      0.995       0.81
# ...

# %%
from ultralytics import YOLO

model = YOLO('/home/pmachado3/code/DDS_bootcamp_project/Malaria_Tracker/models/best_multiclass.pt')

# %%
model.val(data='data.yaml', project = '../runs_draft/', save=True, plots=True)

# model.predict(
#    source='https://media.roboflow.com/notebooks/examples/dog.jpeg',
#    conf=0.25
# )
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.12 torch-2.0.1+cu117 CUDA:0 (Quadro RTX 4000, 8192MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /home/pmachado3/code/DDS_bootcamp_project/Malaria_Tracker/raw_data/task_2/parasite/YOLO_FORMAT_4/valid/lab
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:04<00
#                    all         38        298      0.868      0.868      0.938      0.664
#          0- falciparum         38        276        0.9      0.855      0.906      0.519
#            1- malariae         38          5      0.783          1      0.995       0.81
#               2- ovale         38          7      0.906      0.857      0.978      0.748
#               3- vivax         38         10      0.883      0.759      0.873      0.581
# Speed: 1.5ms pre-process, 10.8ms inference, 0.0ms loss, 22.5ms post-process per image

# %%
abc = model.predict(source='/home/pmachado3/code/DDS_bootcamp_project/Malaria_Tracker/raw_data/task_2/parasite/YOLO_FORMAT_4/valid/images', 
              project = '../runs_draft/', save=True, plots=True, show = True)
# Out:
# Results saved to ../runs_draft/predict2

# %%
abc.
# Out:
# [Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[9.27000e+02, 7.30000e+02, 9.99000e+02, 8.43000e+02, 8.88604e-01, 0.00000e+00]], device='cuda:0'),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([3, 6])
#  dtype: torch.float32
#   + tensor([[8.63000e+02, 8.25000e+02, 9.54000e+02, 9.17000e+02, 9.15525e-01, 0.00000e+00],
#          [9.99000e+02, 1.07700e+03, 1.05000e+03, 1.13900e+03, 3.85072e-01, 0.00000e+00],
#          [1.43800e+03, 2.53000e+02, 1.56000e+03, 4.47000e+02, 3.07456e-01, 0.00000e+00]], device='cuda:0'),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([2, 6])
#  dtype: torch.float32
#   + tensor([[1.19200e+03, 6.40000e+02, 1.24500e+03, 6.88000e+02, 4.81494e-01, 0.00000e+00],
# ...
